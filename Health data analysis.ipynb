# %% [markdown]
# # Analysis

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('task.csv')
df
# Out:
#                              auth0_id answer_created_at  \
# 0      auth0|61ad409f570be3006946663a        2022-05-06
# 1      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-05
# 2      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-05
# 3      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-04
# 4      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-04
# ...                               ...               ...
# 20798  auth0|64eeac27f3d45654eebd4322        2023-08-30
# 20799  auth0|64ef6d28f3d45654eebde6e4        2023-08-30
# 20800  auth0|64ef6d28f3d45654eebde6e4        2023-08-30
# 20801                             NaN        2022-03-10
# 20802                             NaN        2022-03-10
#
#                                                      key  \
# 0                                              important
# 1                                                symptom
# 2                                              important
# 3                                                symptom
# ...

# %%
df2=df.drop(columns=['IDENTIFIED_CATEGORY_LIST'])

# %%
index_to_retrieve = 20799
y= df2.loc[index_to_retrieve]
g=y['key']
g
# Out:
# "What is the biggest goal or improvement you'd like to focus on while working with Lifeforce?"

# %%
grouped = df2.groupby('key')
grouped_data = dict(list(grouped))

# Access a specific group DataFrame
specific_group = grouped_data['important']
grouped_data.keys()
# Out:
# dict_keys(["What is the biggest goal or improvement you'd like to focus on while working with Lifeforce?", 'What is your biggest complaint or concern you would like to address while working with Lifeforce?', 'important', 'symptom'])

# %%
grouped_items = list(grouped_data.items())
index_to_retrieve = 0
if index_to_retrieve < len(grouped_items):
    df1name, df1 = grouped_items[index_to_retrieve]
    print(f"Group key at index {index_to_retrieve}: {df1name}")
    print(f"Group dataframe at index {index_to_retrieve}:")
else:
    print(f"Index {index_to_retrieve} is out of range.")
    
df1
# Out:
# Group key at index 0: What is the biggest goal or improvement you'd like to focus on while working with Lifeforce?
# Group dataframe at index 0:
#                              auth0_id answer_created_at  \
# 9      auth0|6202f5552892ac0071c0d321        2023-08-14
# 18     auth0|6204073b8aeaf7006baec6cb        2022-11-02
# 20     auth0|62040fdc8aeaf7006baed3bb        2022-09-26
# 23     auth0|62040fdc8aeaf7006baed3bb        2023-03-18
# 25     auth0|620428f7c296ad0069c55669        2022-07-12
# ...                               ...               ...
# 20791  auth0|64ee1b02ec54fd186ab7819e        2023-08-29
# 20794  auth0|64ee22ee18ca21cde2298349        2023-08-29
# 20796  auth0|64ee94cdf3d45654eebd2c6e        2023-08-30
# 20798  auth0|64eeac27f3d45654eebd4322        2023-08-30
# 20799  auth0|64ef6d28f3d45654eebde6e4        2023-08-30
#
#                                                      key  \
# 9      What is the biggest goal or improvement you'd ...
# ...

# %%
import re

text = "west has been having good health"

pattern = r'\b\w+\W+(health)\b'
match = re.search(pattern, text, re.IGNORECASE)

if match:
    extracted_text = match.group(0)
    print(extracted_text)
else:
    print("Pattern not found")
# Out:
# good health

# %%
# zxq=df1['value'].dropna()
pt=
zxq=df1[df1['value'].str.contains('health', case=False, na=False)]
def extract_words_before_health(value):
    words = value.lower().split()
    
    if 'health' in words:
        health_index = words.index('health')
        bf=words[:health_index]
        vc=re.search(pt,value,re.IGNORECASE)
        extracted_words =vc
        return extracted_words
    elif 'health.' in words:
        health_index = words.index('health.')
        bf=words[:health_index]
        vc=re.search(pt,value,re.IGNORECASE)
        extracted_words =vc
        return extracted_words
    elif 'health/' in words:
        health_index = words.index('health/')
        bf=words[:health_index]
        vc=re.search(pt,value,re.IGNORECASE)
        extracted_words =vc
        return extracted_words
        
    else:
        return None


# Apply the function to the filtered rows
zxq.loc[:, 'extracted_words'] = zxq['value'].apply(extract_words_before_health)
zxq
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18296\3234028657.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zxq.loc[:, 'extracted_words'] = zxq['value'].apply(extract_words_before_health)
#                              auth0_id answer_created_at  \
# 23     auth0|62040fdc8aeaf7006baed3bb        2023-03-18
# 38     auth0|620484ad16548200690f6062        2022-09-20
# 46     auth0|620522f58bb3b10068268d8d        2023-01-05
# 119    auth0|6207129e165482006911d82e        2022-06-23
# 120    auth0|6207129e165482006911d82e        2022-06-22
# ...                               ...               ...
# 20775  auth0|64ecd92bb1596ae874cca3a2        2023-08-29
# 20790  auth0|64ede18c085e44b38c98c43a        2023-08-29
# ...

# %%
pt = r'\b(\w+\W+health)\b'

# Filter rows containing 'health' in the value column
zxq = df1[df1['value'].str.contains('health', case=False, na=False)]

def extract_words_before_health(value):
    words = value.lower().split()
    
    if 'health' in words:
        health_index = words.index('health')
        bf = words[:health_index]
        vc = re.search(pt, value, re.IGNORECASE)
        extracted_words = vc.group(1) if vc else None
        return extracted_words
    elif 'health.' in words:
        health_index = words.index('health.')
        bf = words[:health_index]
        vc = re.search(pt, value, re.IGNORECASE)
        extracted_words = vc.group(1) if vc else None
        return extracted_words
    elif 'health/' in words:
        health_index = words.index('health/')
        bf = words[:health_index]
        vc = re.search(pt, value, re.IGNORECASE)
        extracted_words = vc.group(1) if vc else None
        return extracted_words
    else:
        return None

# Apply the function to the filtered rows
zxq['Extracted_Goal'] = zxq['value'].apply(extract_words_before_health)
zxq
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18296\1219862447.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zxq['Extracted_Goal'] = zxq['value'].apply(extract_words_before_health)
#                              auth0_id answer_created_at  \
# 23     auth0|62040fdc8aeaf7006baed3bb        2023-03-18
# 38     auth0|620484ad16548200690f6062        2022-09-20
# 46     auth0|620522f58bb3b10068268d8d        2023-01-05
# 119    auth0|6207129e165482006911d82e        2022-06-23
# 120    auth0|6207129e165482006911d82e        2022-06-22
# ...                               ...               ...
# 20775  auth0|64ecd92bb1596ae874cca3a2        2023-08-29
# 20790  auth0|64ede18c085e44b38c98c43a        2023-08-29
# ...

# %%
zxq
zxq['Extracted_Goal'] = zxq['Extracted_Goal'].str.lower()


# Group by the 'extracted_words' column
zx1 = zxq.groupby('Extracted_Goal')
gd=dict(list(zx1))
# Access a specific group DataFrame
gd.keys()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18296\3315114640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zxq['Extracted_Goal'] = zxq['Extracted_Goal'].str.lower()
# ...

# %%
zxq['Extracted_Goal'] = zxq['Extracted_Goal'].fillna('overall good health')
zxq
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18296\2241565271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zxq['Extracted_Goal'] = zxq['Extracted_Goal'].fillna('overall good health')
#                              auth0_id answer_created_at  \
# 23     auth0|62040fdc8aeaf7006baed3bb        2023-03-18
# 38     auth0|620484ad16548200690f6062        2022-09-20
# 46     auth0|620522f58bb3b10068268d8d        2023-01-05
# 119    auth0|6207129e165482006911d82e        2022-06-23
# 120    auth0|6207129e165482006911d82e        2022-06-22
# ...                               ...               ...
# 20775  auth0|64ecd92bb1596ae874cca3a2        2023-08-29
# 20790  auth0|64ede18c085e44b38c98c43a        2023-08-29
# ...

# %%
replacement_dict = {
    'optimal health': 'overall good health',
    'good health': 'overall good health',
    'general health': 'overall good health',
    'better health': 'overall good health',
    'optimize health':'overall good health',
    'overall health':'overall good health',
    'of health':'overall good health',
    'my health':'overall good health',
    'and health':'overall good health',
    'all health':'overall good health',
    'optimum health':'overall good health',
    'wholistic health':'overall good health',
    'improve health':'overall good health',
    'best health':'overall good health',
    'optimizing health':'overall good health',
    'main health':'overall good health',
    'improved health':'overall good health',
    'current health':'overall good health',
    'in health':'overall good health',
    'improved health':'overall good health',
    'maintain':'overall good health',
    'great health':'overall good health',
}

zxq['Extracted_Goal'] = zxq['Extracted_Goal'].replace(replacement_dict)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18296\877374109.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zxq['Extracted_Goal'] = zxq['Extracted_Goal'].replace(replacement_dict)

# %%
group_counts = zxq['Extracted_Goal'].value_counts()

# Get the top 10 groups
top_10_groups = group_counts.head(10)
print(top_10_groups)
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_10_groups, labels=top_10_groups.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Groups with Most People')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# overall good health    2719
# mental health            40
# physical health          37
# term health              26
# gut health               26
# maintain health          15
# heart health             15
# brain health             14
# hormone health           11
# metabolic health         10
# Name: Extracted_Goal, dtype: int64

# %%
group_names = list(top_10_groups.index)
group_counts = list(top_10_groups)

plt.figure(figsize=(10, 6))
plt.bar(group_names, group_counts, color='blue')
plt.xlabel('Groups')
plt.ylabel('Count')
plt.title('Top 10 Goals')
plt.xticks(rotation=45, ha="right")
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.tight_layout()
plt.show()

# %%
import re



# Regular expression pattern
re_pattern = r'\b\w+\W+(health)\b'

# Apply the regex pattern to filter rows
filtered_df = df1[df1['value'].str.contains(re_pattern, case=False, na=False)].copy()

# Define a function to extract words before "health"
def extract_words_before_health(value):
    words = value.lower().split()
    try:
        health_index = words.index('health')
        extracted_words = ' '.join(words[:health_index])
        return extracted_words
    except ValueError:
        return None

# Apply the function to the filtered rows
filtered_df['extracted_words'] = filtered_df['value'].apply(extract_words_before_health)

filtered_df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18296\2033894732.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtered_df = df1[df1['value'].str.contains(re_pattern, case=False, na=False)].copy()
#                              auth0_id answer_created_at  \
# 23     auth0|62040fdc8aeaf7006baed3bb        2023-03-18
# 38     auth0|620484ad16548200690f6062        2022-09-20
# 46     auth0|620522f58bb3b10068268d8d        2023-01-05
# 119    auth0|6207129e165482006911d82e        2022-06-23
# 148    auth0|620bbbda179884006ac5596c        2023-07-29
# ...                               ...               ...
# 20759  auth0|64ea6c10d73497292f7213ab        2023-08-28
# 20769  auth0|64ebe0b8ed5615c2aa8c3791        2023-08-29
# 20790  auth0|64ede18c085e44b38c98c43a        2023-08-29
# 20794  auth0|64ee22ee18ca21cde2298349        2023-08-29
# 20798  auth0|64eeac27f3d45654eebd4322        2023-08-30
#
# ...

# %%
df1_cleaned = df1.dropna(subset=['value'])

# Filter rows where any word contains "health"
filtered_rows = df1_cleaned[df1_cleaned['value'].str.split().apply(lambda words: any("health" in word for word in words))].copy()

# Function to extract words before "health"
def extract_words_before_health(value):
    words = value.lower().split()
    health_index = None
    for i, word in enumerate(words):
        if "health" in word:
            health_index = i
            break
    if health_index is not None:
        extracted_words = ' '.join(words[:health_index])
        return extracted_words
    else:
        return None

# Apply the function using .loc to create a new column
filtered_rows.loc[:, 'extracted_words'] = filtered_rows['value'].apply(extract_words_before_health)


filtered_rows
# Out:
#                              auth0_id answer_created_at  \
# 23     auth0|62040fdc8aeaf7006baed3bb        2023-03-18
# 38     auth0|620484ad16548200690f6062        2022-09-20
# 46     auth0|620522f58bb3b10068268d8d        2023-01-05
# 125    auth0|6207e33a4d5502006a6c5ab6        2022-11-18
# 129    auth0|62083fd7b2f36200697e7f83        2023-07-01
# ...                               ...               ...
# 20759  auth0|64ea6c10d73497292f7213ab        2023-08-28
# 20769  auth0|64ebe0b8ed5615c2aa8c3791        2023-08-29
# 20790  auth0|64ede18c085e44b38c98c43a        2023-08-29
# 20794  auth0|64ee22ee18ca21cde2298349        2023-08-29
# 20798  auth0|64eeac27f3d45654eebd4322        2023-08-30
#
#                                                      key  \
# 23     What is the biggest goal or improvement you'd ...
# 38     What is the biggest goal or improvement you'd ...
# 46     What is the biggest goal or improvement you'd ...
# 125    What is the biggest goal or improvement you'd ...
# ...

# %%
index_to_retrieve = 2
if index_to_retrieve < len(grouped_items):
    df3name, df3 = grouped_items[index_to_retrieve]
    print(f"Group key at index {index_to_retrieve}: {df3name}")
    print(f"Group dataframe at index {index_to_retrieve}:")
else:
    print(f"Index {index_to_retrieve} is out of range.")
    
df3
# Out:
# Group key at index 2: important
# Group dataframe at index 2:
#                              auth0_id answer_created_at        key  \
# 0      auth0|61ad409f570be3006946663a        2022-05-06  important
# 2      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-05  important
# 4      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-04  important
# 5      auth0|62028a092892ac0071c0467c        2022-03-14  important
# 7      auth0|62028bb46995ee006ad4d465        2022-03-20  important
# ...                               ...               ...        ...
# 6055   auth0|62ab7989651a4ebd3dd2115d        2022-06-16  important
# 6056   auth0|62ab7b66dd7434a178511304        2022-06-16  important
# 6061   auth0|62ab88bb651a4ebd3dd23057        2022-06-16  important
# 9921   auth0|6336ffc787e7409e768f618d        2022-05-30  important
# 20802                             NaN        2022-03-10  important
#
#                                                    value
# ...

# %%
d=df3['value']
d
# Out:
# 0         ["looking_good", "living_long", "having_energy"]
# 2                          ["looking_good", "lose_weight"]
# 4                          ["looking_good", "lose_weight"]
# 5                     ["looking_good", "mental_sharpness"]
# 7        ["no_sickness", "looking_good", "lose_weight",...
#                                ...
# 6055                ["health_wellbeing", "fit_and_strong"]
# 6056     ["no_sickness", "lose_weight", "living_long", ...
# 6061     ["sexually_active", "looking_good", "lose_weig...
# 9921     ["sexually_active", "lose_weight", "living_lon...
# 20802                                 ["health_wellbeing"]
# Name: value, Length: 2614, dtype: object

# %%
class_counts = df3['value'].explode().value_counts()

# Convert class_counts Series to a DataFrame and reset the index
class_counts_df = class_counts.reset_index()

# Rename the columns
class_counts_df.columns = ['class', 'frequency']

# Sort the DataFrame by frequency in descending order
class_counts_df = class_counts_df.sort_values(by='frequency', ascending=False)

# Reset the index again
class_counts_df.reset_index(drop=True, inplace=True)
ds=class_counts_df.head(10)
print(ds)
plt.figure(figsize=(20, 16))
plt.pie(ds['frequency'], labels=ds['class'], autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Most Important categories chosen by People')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
#                                                class  frequency
# 0  ["sexually_active", "no_sickness", "looking_go...        261
# 1           ["mental_sharpness", "health_wellbeing"]        156
# 2  ["sexually_active", "no_sickness", "looking_go...        132
# 3             ["health_wellbeing", "fit_and_strong"]        132
# 4              ["having_energy", "health_wellbeing"]        110
# 5             ["mental_sharpness", "fit_and_strong"]        100
# 6                ["living_long", "health_wellbeing"]         84
# 7              ["mental_sharpness", "having_energy"]         76
# 8                ["lose_weight", "health_wellbeing"]         65
# 9                               ["health_wellbeing"]         65

# %%
from collections import Counter

# %%
fg=df3['value']
print(type(fg))
# Out:
# <class 'pandas.core.series.Series'>

# %%
categories = [
    "sexually_active",
    "no_sickness",
    "looking_good",
    "mental_sharpness",
    "health_wellbeing",
    "fit_and_strong",
    "living_long",
    "lose_weight"
]

# Create new columns for each category
for category in categories:
    df3[category] = df3['value'].apply(lambda x: category if category in x else None)
    
df3
# Out:
#                              auth0_id answer_created_at        key  \
# 0      auth0|61ad409f570be3006946663a        2022-05-06  important
# 2      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-05  important
# 4      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-04  important
# 5      auth0|62028a092892ac0071c0467c        2022-03-14  important
# 7      auth0|62028bb46995ee006ad4d465        2022-03-20  important
# ...                               ...               ...        ...
# 6055   auth0|62ab7989651a4ebd3dd2115d        2022-06-16  important
# 6056   auth0|62ab7b66dd7434a178511304        2022-06-16  important
# 6061   auth0|62ab88bb651a4ebd3dd23057        2022-06-16  important
# 9921   auth0|6336ffc787e7409e768f618d        2022-05-30  important
# 20802                             NaN        2022-03-10  important
#
#                                                    value  sexually_active  \
# 0       ["looking_good", "living_long", "having_energy"]             None
# ...

# %%
value_counts_per_category = {}
for category in categories:
    value_counts_per_category[category] = df3[category].value_counts(dropna=False)

# Display value counts
for category, value_counts in value_counts_per_category.items():
    print(f"Value counts for '{category}':")
    print(value_counts)
    print()
# Out:
# Value counts for 'sexually_active':
# None               1752
# sexually_active     862
# Name: sexually_active, dtype: int64
#
# Value counts for 'no_sickness':
# None           1807
# no_sickness     807
# Name: no_sickness, dtype: int64
#
# Value counts for 'looking_good':
# None            1788
# looking_good     826
# Name: looking_good, dtype: int64
#
# Value counts for 'mental_sharpness':
# mental_sharpness    1518
# None                1096
# Name: mental_sharpness, dtype: int64
#
# Value counts for 'health_wellbeing':
# health_wellbeing    1761
# None                 853
# Name: health_wellbeing, dtype: int64
#
# Value counts for 'fit_and_strong':
# fit_and_strong    1485
# None              1129
# Name: fit_and_strong, dtype: int64
#
# Value counts for 'living_long':
# None           1516
# living_long    1098
# Name: living_long, dtype: int64
#
# Value counts for 'lose_weight':
# None           1773
# lose_weight     841
# Name: lose_weight, dtype: int64

# %%
accumulated_counts = {}

# Accumulate the counts for the specific category value for each category
for category in categories:
    category_value_counts = value_counts_per_category[category]
    category_count = category_value_counts.get(category, 0)
    accumulated_counts[category] = category_count

# Plotting the accumulated counts in a single bar chart
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(accumulated_counts.keys(), accumulated_counts.values(), color='steelblue')
plt.title("Highest Important factor Values")
plt.xlabel("Category")
plt.ylabel("Number of people that chose")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
index_to_retrieve = 3
if index_to_retrieve < len(grouped_items):
    df4name, df4 = grouped_items[index_to_retrieve]
    print(f"Group key at index {index_to_retrieve}: {df4name}")
    print(f"Group dataframe at index {index_to_retrieve}:")
else:
    print(f"Index {index_to_retrieve} is out of range.")
    
df4
# Out:
# Group key at index 3: symptom
# Group dataframe at index 3:
#                              auth0_id answer_created_at      key  \
# 1      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-05  symptom
# 3      auth0|61dcc2f3dc4d30006a5fa3a5        2022-03-04  symptom
# 6      auth0|62028a092892ac0071c0467c        2022-03-14  symptom
# 10     auth0|6203a8066995ee006ad5e79e        2022-04-15  symptom
# 12     auth0|6203e5b622dd7e006ab98681        2022-03-15  symptom
# ...                               ...               ...      ...
# 6054   auth0|62ab7989651a4ebd3dd2115d        2022-06-16  symptom
# 6057   auth0|62ab7b66dd7434a178511304        2022-06-16  symptom
# 6060   auth0|62ab88bb651a4ebd3dd23057        2022-06-16  symptom
# 9922   auth0|6336ffc787e7409e768f618d        2022-05-30  symptom
# 20801                             NaN        2022-03-10  symptom
#
#                                                    value
# 1                                   ["sexual", "sleepy"]
# ...

# %%
index_to_retrieve = 9922
y= df4.loc[index_to_retrieve]
ty=y['value']
ty
# Out:
# '["worse_memory", "sexual", "sleepy", "work_performance", "athletic_deterioration"]'

# %%
categories = [
    "worse_memory",
    "sexual",
    "sleepy",
    "work_performance",
    "athletic_deterioration"
]

# Create new columns for each category
for category in categories:
    df4[category] = df4['value'].apply(lambda x: category if category in x else None)

# Calculate value counts for each category
value_counts_per_category = {}
for category in categories:
    value_counts_per_category[category] = df4[category].value_counts(dropna=False)

# Plotting the accumulated counts in a single bar chart
accumulated_counts = {}

# Accumulate the counts for the specific category value for each category
for category in categories:
    category_value_counts = value_counts_per_category[category]
    category_count = category_value_counts.get(category, 0)
    accumulated_counts[category] = category_count

# Plotting the bar chart
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(accumulated_counts.keys(), accumulated_counts.values(), color='steelblue')
plt.title("Most picked symptoms Values")
plt.xlabel("Category")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
